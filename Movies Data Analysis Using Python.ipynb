# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv(r'/Users/saqib/Downloads/movies.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.head(5)
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7930
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
df.drop(columns = ['id', 'imdb_id', 'homepage', 'cast', 'tagline', 'overview', 'budget_adj', 'revenue_adj'], inplace = True)

# %%
df.head()
# Out:
#    popularity     budget     revenue                original_title  \
# 0   32.985763  150000000  1513528810                Jurassic World
# 1   28.419936  150000000   378436354            Mad Max: Fury Road
# 2   13.112507  110000000   295238201                     Insurgent
# 3   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4    9.335014  190000000  1506249360                     Furious 7
#
#            director                                           keywords  \
# 0   Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1     George Miller   future|chase|post-apocalyptic|dystopia|australia
# 2  Robert Schwentke  based on novel|revolution|dystopia|sequel|dyst...
# 3       J.J. Abrams              android|spaceship|jedi|space opera|3d
# 4         James Wan                car race|speed|revenge|suspense|car
#
#    runtime                                     genres  \
# 0      124  Action|Adventure|Science Fiction|Thriller
# ...

# %%
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# director                  44
# keywords                1493
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %%
df.dropna(how = 'any',subset = ['genres', 'director'], inplace = True)

# %%
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# director                   0
# keywords                1449
# runtime                    0
# genres                     0
# production_companies     994
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %%
df['production_companies'] = df['production_companies'].fillna(0)
df['keywords'] = df['keywords'].fillna(0)

# %%
df.isnull().sum()
# Out:
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# director                0
# keywords                0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# dtype: int64

# %% [markdown]
# # now let's manipulate data

# %%
df['popularity'] = df['popularity'].round(2)

# %%
df
# Out:
#        popularity     budget     revenue                original_title  \
# 0           32.99  150000000  1513528810                Jurassic World
# 1           28.42  150000000   378436354            Mad Max: Fury Road
# 2           13.11  110000000   295238201                     Insurgent
# 3           11.17  200000000  2068178225  Star Wars: The Force Awakens
# 4            9.34  190000000  1506249360                     Furious 7
# ...           ...        ...         ...                           ...
# 10861        0.08          0           0            The Endless Summer
# 10862        0.07          0           0                    Grand Prix
# 10863        0.07          0           0           Beregis Avtomobilya
# 10864        0.06          0           0        What's Up, Tiger Lily?
# 10865        0.04      19000           0      Manos: The Hands of Fate
#
#                  director                                           keywords  \
# ...

# %%
df.insert(3, 'profit', df.revenue - df.budget)

# %%
df
# Out:
#        popularity     budget     revenue      profit  \
# 0           32.99  150000000  1513528810  1363528810
# 1           28.42  150000000   378436354   228436354
# 2           13.11  110000000   295238201   185238201
# 3           11.17  200000000  2068178225  1868178225
# 4            9.34  190000000  1506249360  1316249360
# ...           ...        ...         ...         ...
# 10861        0.08          0           0           0
# 10862        0.07          0           0           0
# 10863        0.07          0           0           0
# 10864        0.06          0           0           0
# 10865        0.04      19000           0      -19000
#
#                      original_title            director  \
# 0                    Jurassic World     Colin Trevorrow
# 1                Mad Max: Fury Road       George Miller
# 2                         Insurgent    Robert Schwentke
# 3      Star Wars: The Force Awakens         J.J. Abrams
# ...

# %%
df.insert(4, 'roi', df.profit/df.budget)

# %%
df
# Out:
#        popularity     budget     revenue      profit       roi  \
# 0           32.99  150000000  1513528810  1363528810  9.090192
# 1           28.42  150000000   378436354   228436354  1.522909
# 2           13.11  110000000   295238201   185238201  1.683984
# 3           11.17  200000000  2068178225  1868178225  9.340891
# 4            9.34  190000000  1506249360  1316249360  6.927628
# ...           ...        ...         ...         ...       ...
# 10861        0.08          0           0           0       NaN
# 10862        0.07          0           0           0       NaN
# 10863        0.07          0           0           0       NaN
# 10864        0.06          0           0           0       NaN
# 10865        0.04      19000           0      -19000 -1.000000
#
#                      original_title            director  \
# 0                    Jurassic World     Colin Trevorrow
# 1                Mad Max: Fury Road       George Miller
# ...

# %%
df['roi'] = df['roi'].round(2)

# %%
df
# Out:
#        popularity     budget     revenue      profit   roi  \
# 0           32.99  150000000  1513528810  1363528810  9.09
# 1           28.42  150000000   378436354   228436354  1.52
# 2           13.11  110000000   295238201   185238201  1.68
# 3           11.17  200000000  2068178225  1868178225  9.34
# 4            9.34  190000000  1506249360  1316249360  6.93
# ...           ...        ...         ...         ...   ...
# 10861        0.08          0           0           0   NaN
# 10862        0.07          0           0           0   NaN
# 10863        0.07          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10865        0.04      19000           0      -19000 -1.00
#
#                      original_title            director  \
# 0                    Jurassic World     Colin Trevorrow
# 1                Mad Max: Fury Road       George Miller
# 2                         Insurgent    Robert Schwentke
# ...

# %%
df1 = df[['popularity','budget', 'revenue', 'profit', 'roi', 'vote_count', 'vote_average', 'release_year']]

# %%
df.isnull().sum() #so there are null values in 'roi'
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# profit                     0
# roi                     5636
# original_title             0
# director                   0
# keywords                   0
# runtime                    0
# genres                     0
# production_companies       0
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# dtype: int64

# %%
df.roi.value_counts() #check the types of null values
# Out:
# -1.00     1350
# -0.99       29
# -0.98       27
# -0.38       21
#  0.20       19
#           ...
#  4.15        1
#  24.90       1
#  2.32        1
#  6.24        1
#  6.62        1
# Name: roi, Length: 1074, dtype: int64

# %%
non_finite_values = ~np.isfinite(df['roi'])

# %%
non_finite_values.sum()
# Out:
# 5636

# %%
df['roi'] = df['roi'].replace([np.inf, -np.inf], np.nan)
# replace infinite values with NaN

# %%
df1.hist(bins = 20, figsize=(14,12)) 
#that means something was wrong with the dataset
# let's check In [37 ^]
#now it's fixed
plt.show()

# %%
df.popularity.value_counts()
# Out:
# 0.14    193
# 0.28    190
# 0.21    186
# 0.25    182
# 0.20    179
#        ...
# 5.81      1
# 5.08      1
# 3.83      1
# 3.74      1
# 2.68      1
# Name: popularity, Length: 483, dtype: int64

# %%
df
# Out:
#        popularity     budget     revenue      profit   roi  \
# 0           32.99  150000000  1513528810  1363528810  9.09
# 1           28.42  150000000   378436354   228436354  1.52
# 2           13.11  110000000   295238201   185238201  1.68
# 3           11.17  200000000  2068178225  1868178225  9.34
# 4            9.34  190000000  1506249360  1316249360  6.93
# ...           ...        ...         ...         ...   ...
# 10861        0.08          0           0           0   NaN
# 10862        0.07          0           0           0   NaN
# 10863        0.07          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10865        0.04      19000           0      -19000 -1.00
#
#                      original_title            director  \
# 0                    Jurassic World     Colin Trevorrow
# 1                Mad Max: Fury Road       George Miller
# 2                         Insurgent    Robert Schwentke
# ...

# %%
df2 = df.groupby('release_year')['roi'].mean()
df2
df2.plot(kind = 'line')
# Out:
# <Axes: xlabel='release_year'>

# %%
df3 = df.groupby('release_year')['popularity'].sum()
df3.plot(kind = 'line', color = 'red')
plt.xlabel('year', fontsize = 12)
plt.ylabel('popularity')
# Out:
# Text(0, 0.5, 'popularity')

# %%
df4 = df.groupby('release_year')['vote_average'].mean()
df4.plot(kind = 'line', color = 'orange')
plt.xlabel('year', fontsize = 12)
plt.ylabel('Rating')
# Out:
# Text(0, 0.5, 'Rating')

# %%
df5 = df.plot.scatter(x = 'popularity', y ='vote_average', color = 'green', figsize = (6,4))
df5.set_xlabel('Popularity', color ='DarkRed')
df5.set_ylabel('Vote_Average', color ='DarkRed')
df5.set_title('Popularity vs Vote_Average ', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Popularity vs Vote_Average ')

# %%
df.genres.value_counts()
# Out:
# Drama                                      711
# Comedy                                     707
# Documentary                                306
# Drama|Romance                              289
# Comedy|Drama                               280
#                                           ...
# Science Fiction|Horror|Action|Thriller       1
# Action|Thriller|Science Fiction|Mystery      1
# Comedy|Music|Romance|Foreign                 1
# Documentary|Drama|Comedy                     1
# Mystery|Science Fiction|Thriller|Drama       1
# Name: genres, Length: 2031, dtype: int64

# %%
split = ['genres']
for i in split:
    df[i] =df[i].apply(lambda x: x.split('|'))
df.head(5)
# Out:
#    popularity     budget     revenue      profit   roi  \
# 0       32.99  150000000  1513528810  1363528810  9.09
# 1       28.42  150000000   378436354   228436354  1.52
# 2       13.11  110000000   295238201   185238201  1.68
# 3       11.17  200000000  2068178225  1868178225  9.34
# 4        9.34  190000000  1506249360  1316249360  6.93
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 1            Mad Max: Fury Road     George Miller
# 2                     Insurgent  Robert Schwentke
# 3  Star Wars: The Force Awakens       J.J. Abrams
# 4                     Furious 7         James Wan
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island      124
# 1   future|chase|post-apocalyptic|dystopia|australia      120
# 2  based on novel|revolution|dystopia|sequel|dyst...      119
# 3              android|spaceship|jedi|space opera|3d      136
# ...

# %%
df = df.explode('genres')
df
# Out:
#        popularity     budget     revenue      profit   roi  \
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 1           28.42  150000000   378436354   228436354  1.52
# ...           ...        ...         ...         ...   ...
# 10863        0.07          0           0           0   NaN
# 10863        0.07          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10865        0.04      19000           0      -19000 -1.00
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# ...

# %%
df7 = df.groupby('genres')['popularity'].sum().sort_values(ascending = True)
df7
# Out:
# genres
# Foreign              35.24
# TV Movie             44.03
# Documentary          93.13
# Western              97.42
# History             192.35
# War                 196.48
# Music               198.15
# Mystery             558.55
# Animation           594.46
# Horror              761.39
# Fantasy             908.87
# Family              967.06
# Crime              1009.07
# Romance            1013.21
# Science Fiction    1230.41
# Adventure          1697.11
# Thriller           2155.90
# Action             2208.08
# Comedy             2246.25
# Drama              2815.43
# Name: popularity, dtype: float64

# %%
df.genres.value_counts()
# now compare this with In[58 ^]
# Out:
# Drama              4755
# Comedy             3782
# Thriller           2905
# Action             2379
# Romance            1708
# Horror             1636
# Adventure          1466
# Crime              1354
# Science Fiction    1224
# Family             1223
# Fantasy             912
# Mystery             809
# Animation           692
# Documentary         509
# Music               402
# History             332
# War                 270
# Foreign             185
# Western             164
# TV Movie            162
# Name: genres, dtype: int64

# %%
df7.plot.barh(x = 'genres', y = 'popularity', color = 'red', figsize =(12,6))
# Out:
# <Axes: ylabel='genres'>

# %%
df.head(1) 
#we can surely see that 'release_date' is not date type
# Out:
#    popularity     budget     revenue      profit   roi  original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09  Jurassic World
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
#
#    runtime  genres                               production_companies  \
# 0      124  Action  Universal Studios|Amblin Entertainment|Legenda...
#
#   release_date  vote_count  vote_average  release_year
# 0       6/9/15        5562           6.5          2015

# %%
df.dtypes
# as we can see that 'release_date' is 'object'  type
# Out:
# popularity              float64
# budget                    int64
# revenue                   int64
# profit                    int64
# roi                     float64
# original_title           object
# director                 object
# keywords                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# dtype: object

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.dtypes
# date time fixed!
# Out:
# popularity                     float64
# budget                           int64
# revenue                          int64
# profit                           int64
# roi                            float64
# original_title                  object
# director                        object
# keywords                        object
# runtime                          int64
# genres                          object
# production_companies            object
# release_date            datetime64[ns]
# vote_count                       int64
# vote_average                   float64
# release_year                     int64
# dtype: object

# %%
df.head(5)
# Out:
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1    George Miller   future|chase|post-apocalyptic|dystopia|australia
#
#    runtime           genres  \
# 0      124           Action
# 0      124        Adventure
# ...

# %%
df['extracted_month'] = df['release_date'].dt.month

# %%
df
# Out:
#        popularity     budget     revenue      profit   roi  \
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 0           32.99  150000000  1513528810  1363528810  9.09
# 1           28.42  150000000   378436354   228436354  1.52
# ...           ...        ...         ...         ...   ...
# 10863        0.07          0           0           0   NaN
# 10863        0.07          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10864        0.06          0           0           0   NaN
# 10865        0.04      19000           0      -19000 -1.00
#
#                  original_title          director  \
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# 0                Jurassic World   Colin Trevorrow
# ...

# %%
df8 = df.groupby('extracted_month')['popularity'].sum()

# %%
df8
# Out:
# extracted_month
# 1     1131.78
# 2     1092.93
# 3     1458.32
# 4     1191.81
# 5     1687.53
# 6     1936.84
# 7     1694.03
# 8     1432.59
# 9     1872.28
# 10    1811.91
# 11    1710.35
# 12    2002.22
# Name: popularity, dtype: float64

# %%
data = {
    'extracted_month': df8.index,
    'popularity' : df8.values
}
df8 = pd.DataFrame(data)

# %%
df8
# Out:
#     extracted_month  popularity
# 0                 1     1131.78
# 1                 2     1092.93
# 2                 3     1458.32
# 3                 4     1191.81
# 4                 5     1687.53
# 5                 6     1936.84
# 6                 7     1694.03
# 7                 8     1432.59
# 8                 9     1872.28
# 9                10     1811.91
# 10               11     1710.35
# 11               12     2002.22

# %%
index_to_months = {
    1: 'January',
    2: 'February',
    3: 'March',
    4: 'April',
    5: 'May',
    6: 'June',
    7: 'July',
    8: 'August',
    9: 'September',
    10:'October',
    11:'November',
    12:'December'
}

# %%
df8.extracted_month = df8.extracted_month.map(index_to_months)

# %%
df8
# Out:
#    extracted_month  popularity
# 0          January     1131.78
# 1         February     1092.93
# 2            March     1458.32
# 3            April     1191.81
# 4              May     1687.53
# 5             June     1936.84
# 6             July     1694.03
# 7           August     1432.59
# 8        September     1872.28
# 9          October     1811.91
# 10        November     1710.35
# 11        December     2002.22

# %%
df8.plot(kind = 'bar', x = 'extracted_month', y = 'popularity', color = 'darkblue')
# Out:
# <Axes: xlabel='extracted_month'>

# %%
df9 = df.groupby('extracted_month')['revenue'].sum()
df9
# Out:
# extracted_month
# 1      35873456579
# 2      54352852344
# 3      93669046441
# 4      77813179749
# 5     151475532493
# 6     193681776686
# 7     141947570995
# 8      71642408883
# 9      70379641581
# 10     84054172048
# 11    139176268899
# 12    164738399960
# Name: revenue, dtype: int64

# %%
data = {
    'extracted_month': df9.index,
    'revenue': df9.values
}
df9 = pd.DataFrame(data)

# %%
df9.extracted_month = df9.extracted_month.map(index_to_months)

# %%
df9
# Out:
#    extracted_month       revenue
# 0          January   35873456579
# 1         February   54352852344
# 2            March   93669046441
# 3            April   77813179749
# 4              May  151475532493
# 5             June  193681776686
# 6             July  141947570995
# 7           August   71642408883
# 8        September   70379641581
# 9          October   84054172048
# 10        November  139176268899
# 11        December  164738399960

# %%
df9.plot(kind = 'bar', x = 'extracted_month', y = 'revenue', color = 'darkblue')
plt.title('Revenue by Month')
plt.ylabel('Revenue')
plt.xlabel('Month')
plt.show()

# %%
df.head()
# Out:
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1    George Miller   future|chase|post-apocalyptic|dystopia|australia
#
#    runtime           genres  \
# 0      124           Action
# 0      124        Adventure
# ...

# %%
df10 = df.groupby('original_title')['profit'].sum().sort_values(ascending = False).head(5)

# %%
df10.plot(kind = 'pie', autopct = '%1.1f%%', startangle = 90)
# Out:
# <Axes: ylabel='profit'>

# %%
df10.plot(kind = 'pie', autopct = '%1.1f%%', startangle = 90, colors = plt.cm.Paired.colors)
plt.title( 'Top 5 Movies by Profit', color = 'red')
# Out:
# Text(0.5, 1.0, 'Top 5 Movies by Profit')

# %%
df.head()
# Out:
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1    George Miller   future|chase|post-apocalyptic|dystopia|australia
#
#    runtime           genres  \
# 0      124           Action
# 0      124        Adventure
# ...

# %%
df11 = df.production_companies.value_counts().head(5)
df11
# Out:
# 0                       2152
# Paramount Pictures       404
# Universal Pictures       352
# Walt Disney Pictures     236
# Warner Bros.             225
# Name: production_companies, dtype: int64

# %%
explode_list = [0,0,0.4,0,0 # used to get piece from pie chart 
df11.plot(kind = 'pie', figsize = (13,10), autopct = '%1.1f%%', startangle = 90, labels = None, pctdistance = 1.14, explode = explode_list)
#plt.title( 'Top 5 Movies by Profit', color = 'red')
plt.legend(labels = df11.index, loc = 'upper right')
plt.axis('equal')
plt.show()

# %%
df.head()
# Out:
#    popularity     budget     revenue      profit   roi      original_title  \
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 0       32.99  150000000  1513528810  1363528810  9.09      Jurassic World
# 1       28.42  150000000   378436354   228436354  1.52  Mad Max: Fury Road
#
#           director                                           keywords  \
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 0  Colin Trevorrow  monster|dna|tyrannosaurus rex|velociraptor|island
# 1    George Miller   future|chase|post-apocalyptic|dystopia|australia
#
#    runtime           genres  \
# 0      124           Action
# 0      124        Adventure
# ...

# %%
df12 = df.keywords.value_counts().head(15)
df12
# Out:
# 0                                  3262
# woman director                      238
# independent film                    177
# suspense                             68
# musical                              57
# sport                                50
# duringcreditsstinger                 49
# holiday                              38
# biography                            26
# dystopia                             26
# independent film|woman director      23
# holiday|christmas                    23
# sequel                               19
# based on novel                       18
# christmas                            18
# Name: keywords, dtype: int64

# %%
df12.index
# Out:
# Index([                                0,                  'woman director',
#                       'independent film',                        'suspense',
#                                'musical',                           'sport',
#                   'duringcreditsstinger',                         'holiday',
#                              'biography',                        'dystopia',
#        'independent film|woman director',               'holiday|christmas',
#                                 'sequel',                  'based on novel',
#                              'christmas'],
#       dtype='object')

# %%
data = {
    'keyword': df12.index,
    'value': df12.values
}
df12 = pd.DataFrame(data)

# %%
df12
# Out:
#                             keyword  value
# 0                                 0   3262
# 1                    woman director    238
# 2                  independent film    177
# 3                          suspense     68
# 4                           musical     57
# 5                             sport     50
# 6              duringcreditsstinger     49
# 7                           holiday     38
# 8                         biography     26
# 9                          dystopia     26
# 10  independent film|woman director     23
# 11                holiday|christmas     23
# 12                           sequel     19
# 13                   based on novel     18
# 14                        christmas     18

# %%
fig = px.treemap(df12, path = ['keywords'], values = 'value')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[150], line 1
# ----> 1 fig = px.treemap(df12, path = ['keywords'], values = 'value')
#       2 fig.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_chart_types.py:1591, in treemap(data_frame, names, values, parents, ids, path, color, color_continuous_scale, range_color, color_continuous_midpoint, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, labels, title, template, width, height, branchvalues, maxdepth)
#    1589 if path is not None and branchvalues is None:
#    1590     branchvalues = "total"
# -> 1591 return make_figure(
#    1592     args=locals(),
#    1593     constructor=go.Treemap,
#    1594     trace_patch=dict(branchvalues=branchvalues, maxdepth=maxdepth),
#    1595     layout_patch=layout_patch,
#    1596 )
#
# ...
