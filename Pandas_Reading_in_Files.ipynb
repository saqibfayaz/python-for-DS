# %%
import pandas as pd

# %%
df = pd.read_csv(r'/Users/saqib/Downloads/python tutorial/excel files/extracted_Companies_data_using_webScraping.csv')

# %%
#and suppose if we didn't had names of columns then we could have done this
# pd.read_csv(r'/Users/saqib/Downloads/python tutorial/excel files/extracted_Companies_data_using_webScraping.csv',header= None, names= ['Name','Industry','Revenue (USD millions)','Revenue growth', 'Employees','Headquarters'])

# %%
#import text files
#df = pd.read_csv(r'/Users/saqib/Downloads/python tutorial/excel files/example.text',sep = '\t')

# %%
#or we could have imported text files as this so no seperator could be needed
#df = pd.read_table(r'/Users/saqib/Downloads/python tutorial/excel files/example.text')

# %%
#to read json files
# df = pd.read_json(r'path/example.json')

# %%
df2 = pd.read_excel(r'/Users/saqib/Downloads/python tutorial/excel files/test.xlsx')
df2
#by default it will read the first sheet
# Out:
# Empty DataFrame
# Columns: [sasa]
# Index: []

# %%
#for reading particular sheet
df2 = pd.read_excel(r'/Users/saqib/Downloads/python tutorial/excel files/test.xlsx', sheet_name='Sheet2')
df2
# Out:
# Empty DataFrame
# Columns: [sheets 2 inside]
# Index: []

# %%
#to see all the data and not snapshot
pd.set_option('display.max.rows',100)
df = pd.read_csv(r'/Users/saqib/Downloads/python tutorial/excel files/extracted_Companies_data_using_webScraping.csv')

# %%
#same can be done with coulmns
#pd.set_option('display.max.columns',number of columns yu want to see eg 20 or 100)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sheets 2 inside  0 non-null      object
# dtypes: object(1)
# memory usage: 0.0+ bytes

# %%
df.head()
# Out:
#    Rank                Name                    Industry  \
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare
#
#   Revenue (USD millions) Revenue growth  Employees           Headquarters
# 0               6,11,289          6.70%  21,00,000  Bentonville, Arkansas
# 1               5,13,983          9.40%  15,40,000    Seattle, Washington
# 2               4,13,680         44.80%     62,000          Spring, Texas
# 3               3,94,328          7.80%   1,64,000  Cupertino, California
# 4               3,24,162         12.70%   4,00,000  Minnetonka, Minnesota

# %%
df.head(10)
# Out:
#    Rank                  Name                        Industry  \
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0               6,11,289          6.70%  21,00,000      Bentonville, Arkansas
# 1               5,13,983          9.40%  15,40,000        Seattle, Washington
# ...

# %%
df.tail(10)
# Out:
#     Rank                      Name                 Industry  \
# 90    91         American Airlines                  Airline
# 91    92                       CHS  Agriculture cooperative
# 92    93    Performance Food Group          Food processing
# 93    94                PBF Energy       Petroleum industry
# 94    95                      Nike                  Apparel
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology
#
#    Revenue (USD millions) Revenue growth Employees  \
# 90                 48,971         63.90%  1,29,700
# 91                 47,194         24.30%    10,014
# 92                 47,194         61.60%    34,825
# 93                 46,830         71.80%     3,616
# ...

# %%
df['Name']
# Out:
# 0                                 Walmart
# 1                                  Amazon
# 2                              ExxonMobil
# 3                                   Apple
# 4                      UnitedHealth Group
# 5                              CVS Health
# 6                      Berkshire Hathaway
# 7                                Alphabet
# 8                    McKesson Corporation
# 9                     Chevron Corporation
# 10                      AmerisourceBergen
# 11                                 Costco
# 12                              Microsoft
# 13                        Cardinal Health
# 14                                  Cigna
# 15                     Marathon Petroleum
# 16                            Phillips 66
# 17                          Valero Energy
# 18                     Ford Motor Company
# 19                         The Home Depot
# 20                         General Motors
# 21                        Elevance Health
# ...

# %%
#for index
df.loc[98]
# Out:
# Rank                                            99
# Name                      Thermo Fisher Scientific
# Industry                    Laboratory instruments
# Revenue (USD millions)                      44,915
# Revenue growth                              14.50%
# Employees                                 1,30,000
# Headquarters                Waltham, Massachusetts
# Name: 98, dtype: object

# %%
df.iloc[98]
# Out:
# Rank                                            99
# Name                      Thermo Fisher Scientific
# Industry                    Laboratory instruments
# Revenue (USD millions)                      44,915
# Revenue growth                              14.50%
# Employees                                 1,30,000
# Headquarters                Waltham, Massachusetts
# Name: 98, dtype: object
