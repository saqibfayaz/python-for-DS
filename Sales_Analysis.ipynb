# %% [markdown]
# ## Sales_Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_excel(r'/Users/saqib/Downloads/superstore_sales.xlsx')

# %%
df.head()
# Out:
#           order_id order_date  ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class  Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class    Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class     Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name    sales  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
product_name_sales = pd.DataFrame(df.groupby(['product_name']).sum(numeric_only= True)['sales'])[:5] # we could do this instead of using .head(5)
product_name_sales.sort_values(by = ['sales'], ascending= False, inplace= True)
product_name_sales
# Out:
#                                                       sales
# product_name
# #10 White Business Envelopes,4 1/8 x 9 1/2          488.904
# #10- 4 1/8" x 9 1/2" Recycled Envelopes             286.672
# #10 Self-Seal White Envelopes                       108.682
# #10 Gummed Flap White Envelopes, 100/Box             41.300
# "While you Were Out" Message Book, One Form per...   25.228

# %%
product_name_sales.index
# Out:
# Index(['#10 White Business Envelopes,4 1/8 x 9 1/2',
#        '#10- 4 1/8" x 9 1/2" Recycled Envelopes',
#        '#10 Self-Seal White Envelopes',
#        '#10 Gummed Flap White Envelopes, 100/Box',
#        '"While you Were Out" Message Book, One Form per Page'],
#       dtype='object', name='product_name')

# %%
plt.figure(figsize=(5,3)) # to adjust plot size
plt.bar(product_name_sales.index, product_name_sales['sales'])
plt.xticks(rotation = 'vertical', size = 8) # to rotate labels on x-axis
plt.show()

# %%
df[['segment', 'profit']]
# Out:
#            segment    profit
# 0         Consumer  106.1400
# 1         Consumer   36.0360
# 2         Consumer   29.6400
# 3      Home Office  -26.0550
# 4         Consumer   37.7700
# ...            ...       ...
# 51285    Corporate    4.5188
# 51286     Consumer    0.4200
# 51287     Consumer   12.3600
# 51288     Consumer    0.5600
# 51289     Consumer   -0.6048
#
# [51290 rows x 2 columns]

# %%
product_name_profit = pd.DataFrame(df.groupby(['segment']).sum(numeric_only= True)['profit'])[:5] # we could do this instead of using .head(5)
product_name_profit.sort_values(by = ['profit'], ascending= False, inplace= True)
product_name_profit
# Out:
#                    profit
# segment
# Consumer     749239.78206
# Corporate    442785.85866
# Home Office  277009.18056

# %%
sns.barplot(x = 'segment', y = 'profit', data = product_name_profit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 sns.barplot(x = 'segment', y = 'profit', data = product_name_profit)
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
#    2761     ax = plt.gca()
#
# ...

# %%
# Could not interpret input 'segment'
# so let's reset the index to make 'segment a column'
sns.barplot(x = 'segment', y = 'profit', data = product_name_profit.reset_index())
plt.show()

# %%
pd.DataFrame(df.groupby(['category', 'sub_category']).sum(numeric_only= True)['quantity'])
# Out:
#                               quantity
# category        sub_category
# Furniture       Bookcases         8310
#                 Chairs           12336
#                 Furnishings      11225
#                 Tables            3083
# Office Supplies Appliances        6078
#                 Art              16301
#                 Binders          21429
#                 Envelopes         8380
#                 Fasteners         8390
#                 Labels            9322
#                 Paper            12822
#                 Storage          16917
#                 Supplies          8543
# Technology      Accessories      10946
#                 Copiers           7454
#                 Machines          4906
#                 Phones           11870

# %%
category_name =  sns.FacetGrid(df, col = 'ship_mode')
category_name.map(plt.hist, 'category')
# Out:
# /Users/saqib/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.head(1)
#df.dtypes, so it's datetime , we need to convert 
#it before extracting month
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %%
month = df['order_date'].astype(str)
month = month.apply(lambda x: datetime.strptime(x, '%Y-%m-%d' ))
df['month'] = month.map(lambda x: x.month)
df
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
date = df.groupby(['year', 'month']).sum()
date
# Out:
# /var/folders/2c/hpk9j8md6h71406dzkc5_w1m0000gn/T/ipykernel_20011/4293165847.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   date = df.groupby(['year', 'month']).sum()
#                    sales  quantity  discount       profit  shipping_cost
# year month
# 2011 1       98898.48886      1463    68.758   8321.80096    10544.78800
#      2       91152.15698      1224    52.252  12417.90698    10681.16300
#      3      145729.36736      1836    74.212  15303.56826    13096.18550
#      4      116915.76418      2020    80.782  12902.32438    12954.52000
#      5      146747.83610      2013    82.382  12183.82870    16443.20600
#      6      215207.38022      3112   159.534  23415.24702    23813.10900
#      7      115510.41912      1774    80.086   5585.00352    11844.47600
# ...

# %%
sns.barplot(x = 'year', y = 'sales', data = date.reset_index())
# Out:
# <Axes: xlabel='year', ylabel='sales'>

# %%
df
# Out:
#               order_id order_date  ship_date       ship_mode  \
# 0         AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# 1        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# 2         HU-2011-1220 2011-01-01 2011-01-05    Second Class
# 3      IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# 4        IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# ...                ...        ...        ...             ...
# 51285   CA-2014-115427 2014-12-31 2015-01-04  Standard Class
# 51286     MO-2014-2560 2014-12-31 2015-01-05  Standard Class
# 51287   MX-2014-110527 2014-12-31 2015-01-02    Second Class
# 51288   MX-2014-114783 2014-12-31 2015-01-06  Standard Class
# 51289   CA-2014-156720 2014-12-31 2015-01-04  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
countries = pd.DataFrame(df.groupby('country').sum(numeric_only= True)['sales'])
countries.sort_values('sales', inplace= True, ascending= False)
countries_top_10 = countries.head(10)
countries_top_10
# Out:
#                        sales
# country
# United States   2.297201e+06
# Australia       9.252359e+05
# France          8.589311e+05
# China           7.005620e+05
# Germany         6.288400e+05
# Mexico          6.225906e+05
# India           5.896501e+05
# United Kingdom  5.285763e+05
# Indonesia       4.048875e+05
# Brazil          3.611064e+05

# %%
countries_top_10['sales'].plot(kind = 'pie', autopct = '%1.1f%%', figsize = (10,5))
plt.title('Top 10 Countries by Sales')
# Out:
# Text(0.5, 1.0, 'Top 10 Countries by Sales')

# %%
countries_top_10_shipping_cost =df.groupby(['country']).agg({'shipping_cost': 'max'}).sort_values('shipping_cost', ascending = False).head(10)

# %%
countries_top_10_shipping_cost
# Out:
#                shipping_cost
# country
# United States         933.57
# Australia             923.63
# Germany               910.16
# Senegal               903.04
# New Zealand           894.77
# Afghanistan           835.57
# Saudi Arabia          832.41
# Brazil                810.25
# China                 804.54
# France                801.66

# %%
plt.figure(figsize= (5,3))
plt.bar(countries_top_10_shipping_cost.index, countries_top_10_shipping_cost['shipping_cost'], color = 'red')
plt.xticks(rotation = 'vertical', size = 6)
plt.show()
